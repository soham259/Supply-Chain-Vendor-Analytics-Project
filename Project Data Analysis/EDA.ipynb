# %%
import pandas as pd

# %%
import sqlite3
conn = sqlite3.connect('inventory.db')

# %%
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'",conn)
tables
# Out:
#                    name
# 0       begin_inventory
# 1         end_inventory
# 2             purchases
# 3       purchase_prices
# 4                 sales
# 5        vendor_invoice
# 6  vendor_sales_summary

# %%
pd.read_sql('select count(*) from purchases',conn)
# Out:
#    count(*)
# 0   2372474

# %%
for table in tables['name']:
    print('-'*50,f'{table}','-'*50)
    print('count of records:',pd.read_sql(f'select count(*) as count from {table}',conn)['count'].values[0])
    display(pd.read_sql(f'select * from {table} limit 5',conn))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# count of records: 206529
#    index        InventoryId  Store          City  Brand  \
# 0      0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1      1  1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2      2  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3      3  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4      4  1_HARDERSFIELD_72      1  HARDERSFIELD     72
#
#                    Description   Size  onHand  Price   startDate
# 0  Gekkeikan Black & Gold Sake  750mL       8  12.99  2024-01-01
# 1       Canadian Club 1858 VAP  750mL       7  10.99  2024-01-01
# 2     Herradura Silver Tequila  750mL       6  36.99  2024-01-01
# 3   Herradura Reposado Tequila  750mL       3  38.99  2024-01-01
# 4         No. 3 London Dry Gin  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory --------------------------------------------------
# count of records: 224489
#    index        InventoryId  Store          City  Brand  \
# 0      0  1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1      1  1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 2      2  1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 3      3  1_HARDERSFIELD_72      1  HARDERSFIELD     72
# 4      4  1_HARDERSFIELD_75      1  HARDERSFIELD     75
#
#                    Description   Size  onHand  Price     endDate
# 0  Gekkeikan Black & Gold Sake  750mL      11  12.99  2024-12-31
# 1     Herradura Silver Tequila  750mL       7  36.99  2024-12-31
# 2   Herradura Reposado Tequila  750mL       7  38.99  2024-12-31
# 3         No. 3 London Dry Gin  750mL       4  34.99  2024-12-31
# 4    Three Olives Tomato Vodka  750mL       7  14.99  2024-12-31
# -------------------------------------------------- purchases --------------------------------------------------
# count of records: 2372474
#    index          InventoryId  Store  Brand                   Description  \
# 0      0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno
# 1      1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 2      2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 3      3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 4      4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel
#
#     Size  VendorNumber                   VendorName  PONumber      PODate  \
# 0  750mL           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4  750mL           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    2024-01-02  2024-01-04  2024-02-16          35.71         6   214.26
# 1    2024-01-01  2024-01-07  2024-02-21           9.35         4    37.40
# 2    2024-01-02  2024-01-07  2024-02-21           9.41         5    47.05
# 3    2024-01-01  2024-01-07  2024-02-21           9.35         6    56.10
# 4    2024-01-02  2024-01-09  2024-02-16          21.32         5   106.60
#
#    Classification
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# -------------------------------------------------- purchase_prices --------------------------------------------------
# count of records: 12261
#    index  Brand                  Description  Price   Size Volume  \
# 0      0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750
# 1      1     62     Herradura Silver Tequila  36.99  750mL    750
# 2      2     63   Herradura Reposado Tequila  38.99  750mL    750
# 3      3     72         No. 3 London Dry Gin  34.99  750mL    750
# 4      4     75    Three Olives Tomato Vodka  14.99  750mL    750
#
#    Classification  PurchasePrice  VendorNumber                   VendorName
# 0               1           9.28          8320  SHAW ROSS INT L IMP LTD
# 1               1          28.67          1128  BROWN-FORMAN CORP
# 2               1          30.46          1128  BROWN-FORMAN CORP
# 3               1          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4               1          10.94          7245  PROXIMO SPIRITS INC.
# -------------------------------------------------- sales --------------------------------------------------
# count of records: 12825363
#    index          InventoryId  Store  Brand                 Description  \
# 0      0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1      1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2      2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3      3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4      4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0       750mL              1         16.49       16.49  2024-01-01   750.0
# 1       750mL              2         32.98       16.49  2024-01-02   750.0
# 2       750mL              1         16.49       16.49  2024-01-03   750.0
# 3       750mL              1         14.49       14.49  2024-01-08   750.0
# 4  375mL 2 Pk              2         69.98       34.99  2024-01-09   375.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79     12546  JIM BEAM BRANDS COMPANY
# 1               1       1.57     12546  JIM BEAM BRANDS COMPANY
# 2               1       0.79     12546  JIM BEAM BRANDS COMPANY
# 3               1       0.79     12546  JIM BEAM BRANDS COMPANY
# 4               1       0.79     12546  JIM BEAM BRANDS COMPANY
# -------------------------------------------------- vendor_invoice --------------------------------------------------
# count of records: 5543
#    index  VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0      0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1      1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2      2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3      3           480  BACARDI USA INC              2024-01-12      8106
# 4      4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47     None
# 1  2023-12-22  2024-02-21        15     140.55     8.57     None
# 2  2023-12-24  2024-02-16         5     106.60     4.61     None
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20     None
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20     None
# -------------------------------------------------- vendor_sales_summary --------------------------------------------------
# count of records: 10692
#    VendorNumber                VendorName  Brand  ACTUALPrice  Volume  \
# 0          1128         BROWN-FORMAN CORP   1233        36.99  1750.0
# 1          4425     MARTIGNETTI COMPANIES   3405        28.99  1750.0
# 2         17035         PERNOD RICARD USA   8068        24.99  1750.0
# 3          3960  DIAGEO NORTH AMERICA INC   4261        22.99  1750.0
# 4          3960  DIAGEO NORTH AMERICA INC   3545        29.99  1750.0
#
#    PurchasePrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          26.27                 145080            3811251.60
# 1          23.19                 164038            3804041.22
# 2          18.24                 187407            3418303.68
# 3          16.17                 201682            3261197.94
# 4          21.89                 138109            3023206.01
#
#    TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  TotalExciseTax  \
# 0         5101919.51        672819.31            142049.0       260999.20
# 1         4819073.49        561512.37            160247.0       294438.66
# 2         4538120.60        461140.15            187140.0       343854.07
# 3         4475972.88        420050.01            200412.0       368242.80
# 4         4223107.62        545778.28            135838.0       249587.83
#
#    FreightCost  GrossProfit  ProfitMargin  StockTurnover  SalestoPurchaseRatio
# 0     68601.68   1290667.91      0.252977       0.979108              1.338647
# 1    144929.24   1015032.27      0.210628       0.976890              1.266830
# 2    123780.22   1119816.92      0.246758       0.998575              1.327594
# 3    257032.07   1214774.94      0.271399       0.993703              1.372493
# 4    257032.07   1199901.61      0.284128       0.983556              1.396897

# %%
purchase = pd.read_sql('SELECT * from purchases WHERE VendorNumber = 4466',conn)
purchase.head()
# Out:
#    index          InventoryId  Store  Brand                   Description  \
# 0      1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 1      2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 2      3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 3   8091    38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced
# 4   8092  59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced
#
#     Size  VendorNumber                   VendorName  PONumber      PODate  \
# 0  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 1  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
# 4  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    2024-01-01  2024-01-07  2024-02-21           9.35         4    37.40
# 1    2024-01-02  2024-01-07  2024-02-21           9.41         5    47.05
# 2    2024-01-01  2024-01-07  2024-02-21           9.35         6    56.10
# 3    2024-01-07  2024-01-19  2024-02-26           9.41         6    56.46
# 4    2024-01-05  2024-01-19  2024-02-26           9.41         6    56.46
#
#    Classification
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
purchase_price = pd.read_sql('SELECT * from purchase_prices WHERE VendorNumber = 4466',conn)
purchase_price.head()
# Out:
#    index  Brand                   Description  Price    Size Volume  \
# 0   1197   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750
# 1   1212   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750
# 2   9962   3140      TGI Fridays Orange Dream  14.99  1750mL   1750
#
#    Classification  PurchasePrice  VendorNumber                   VendorName
# 0               1           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1               1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2               1          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
sales = pd.read_sql('SELECT * from sales WHERE VendorNo = 4466',conn)
sales.head()
# Out:
#    index          InventoryId  Store  Brand                   Description  \
# 0  13370  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 1  13371  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 2  13372  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 3  13373  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 4  13374  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
#
#     Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  1.75L              1         12.99       12.99  2024-01-09  1750.0
# 1  1.75L              1         12.99       12.99  2024-01-12  1750.0
# 2  1.75L              1         12.99       12.99  2024-01-15  1750.0
# 3  1.75L              1         12.99       12.99  2024-01-21  1750.0
# 4  1.75L              1         12.99       12.99  2024-01-23  1750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       1.84      4466  AMERICAN VINTAGE BEVERAGE
# 1               1       1.84      4466  AMERICAN VINTAGE BEVERAGE
# 2               1       1.84      4466  AMERICAN VINTAGE BEVERAGE
# 3               1       1.84      4466  AMERICAN VINTAGE BEVERAGE
# 4               1       1.84      4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice = pd.read_sql('SELECT * from vendor_invoice WHERE VendorNumber = 4466',conn)
vendor_invoice.head()
# Out:
#    index  VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0      1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1     90          4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2    189          4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3    284          4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4    380          4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2023-12-22  2024-02-21        15   140.55     8.57     None
# 1  2023-12-27  2024-02-26       335  3142.33    16.97     None
# 2  2024-01-03  2024-02-18        41   383.35     1.99     None
# 3  2024-01-14  2024-03-11        72   673.20     3.30     None
# 4  2024-01-19  2024-03-15        79   740.21     3.48     None

# %%
purchase_price.groupby(['Brand'])[['Price','PurchasePrice']].sum()
# Out:
#        Price  PurchasePrice
# Brand
# 3140   14.99          11.19
# 5215   12.99           9.41
# 5255   12.99           9.35

# %%
sales.groupby(['Brand'])[['SalesDollars','SalesPrice']].sum()
# Out:
#        SalesDollars  SalesPrice
# Brand
# 3140       50531.10    30071.85
# 5215       60416.49    41542.02
# 5255       79187.04    51180.60

# %%
query = '''
SELECT 
    v.VendorNumber, v.VendorName, v.PONumber, v.PODate, v.PayDate, 
    v.Quantity AS VendorQuantity, v.Dollars AS VendorDollars, v.Freight, 
    p.InventoryId, p.Store, p.Brand, p.Description, p.Size, 
    p.PurchasePrice, p.Quantity AS PurchaseQuantity, p.Dollars AS PurchaseDollars
FROM 
    vendor_invoice v 
INNER JOIN 
    purchases p 
ON 
    v.PONumber = p.PONumber
'''

df = pd.read_sql(query, conn)

# %%
df.head()
# Out:
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#       PayDate  VendorQuantity  VendorDollars  Freight          InventoryId  \
# 0  2024-02-16               6         214.26     3.47    69_MOUNTMEND_8412
# 1  2024-02-21              15         140.55     8.57  1_HARDERSFIELD_5255
# 2  2024-02-21              15         140.55     8.57     30_CULCHETH_5255
# 3  2024-02-21              15         140.55     8.57    34_PITMERDEN_5215
# 4  2024-02-16               5         106.60     4.61    76_DONCASTER_2034
#
#    Store  Brand                   Description   Size  PurchasePrice  \
# 0     69   8412     Tequila Ocho Plata Fresno  750mL          35.71
# 1      1   5255  TGI Fridays Ultimte Mudslide  1.75L           9.35
# 2     30   5255  TGI Fridays Ultimte Mudslide  1.75L           9.35
# 3     34   5215  TGI Fridays Long Island Iced  1.75L           9.41
# 4     76   2034     Glendalough Double Barrel  750mL          21.32
#
#    PurchaseQuantity  PurchaseDollars
# 0                 6           214.26
# 1                 6            56.10
# 2                 4            37.40
# 3                 5            47.05
# 4                 5           106.60

# %%
freight_summary = pd.read_sql("""select VendorNumber, SUM(Freight) as FreightCost
from vendor_invoice
Group by VendorNumber""",conn)
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0               2        27.08
# 1              54         0.48
# 2              60       367.52
# 3             105        62.39
# 4             200         6.19
# ..            ...          ...
# 121         98450       856.02
# 122         99166       130.09
# 123        172662       178.34
# 124        173357       202.50
# 125        201359         0.09
#
# [126 rows x 2 columns]

# %%
pd.read_sql("""Select 
p.VendorNumber,
p.VendorName,
p.Brand,
p.PurchasePrice,
pp.Volume,
pp.Price as ACTUALPrice,
SUM(p.QUANTITY) as TotalPurchaseQuantity,
SUM(p.Dollars) as TotalPurchaseDollars
from purchases p
join purchase_prices pp
on p.Brand = pp.Brand
where p.PurchasePrice > 0
Group by p.VendorNumber,p.VendorName,p.Brand
order by TotalPurchaseDollars""",conn)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
#        ACTUALPrice  TotalPurchaseQuantity  TotalPurchaseDollars
# 0             0.99                      1                  0.71
# 1             1.99                      1                  1.47
# 2             0.99                      2                  1.48
# 3             0.49                      6                  2.34
# 4             4.99                      2                  2.64
# ...            ...                    ...                   ...
# 10687        29.99                 138109            3023206.01
# 10688        22.99                 201682            3261197.94
# 10689        24.99                 187407            3418303.68
# 10690        28.99                 164038            3804041.22
# 10691        36.99                 145080            3811251.60
#
# [10692 rows x 8 columns]

# %%
pd.read_sql("""SELECT
VendorNo,
Brand,
SUM(SalesDollars) as TotalSalesDollars,
SUM(SalesPrice) as TotalSalesPrice,
SUM(SalesQuantity) as TotalSalesQuantity,
SUM(ExciseTax) as TotalExciseTax
FROM sales
Group by VendorNo,Brand
order by TotalSalesDollars""",conn)
# Out:
#        VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  \
# 0          8004   5287               0.98             0.98
# 1          9206   2773               0.99             0.99
# 2          3252   3933               1.98             0.99
# 3          3924   9123               1.98             0.99
# 4         10050   3623               1.98             1.98
# ...         ...    ...                ...              ...
# 11267      3960   3545         4223107.62        545778.28
# 11268      3960   4261         4475972.88        420050.01
# 11269     17035   8068         4538120.60        461140.15
# 11270      4425   3405         4819073.49        561512.37
# 11271      1128   1233         5101919.51        672819.31
#
#        TotalSalesQuantity  TotalExciseTax
# 0                       2            0.10
# 1                       1            0.05
# 2                       2            0.10
# 3                       2            0.10
# 4                       2            0.10
# ...                   ...             ...
# 11267              135838       249587.83
# 11268              200412       368242.80
# 11269              187140       343854.07
# 11270              160247       294438.66
# 11271              142049       260999.20
#
# [11272 rows x 6 columns]

# %%
vendor_sales_summary = pd.read_sql_query("""
WITH FreightSummary AS (
    SELECT VendorNumber, SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),

purchaseSummary AS (
    SELECT 
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.PurchasePrice,
        pp.Volume,
        pp.Price AS ACTUALPrice,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.PurchasePrice, pp.Volume, pp.Price
),

salesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT 
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.ACTUALPrice,
    ps.Volume,
    ps.PurchasePrice,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalSalesQuantity,
    ss.TotalExciseTax,
    fs.FreightCost
FROM purchaseSummary ps
LEFT JOIN salesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC;
""", conn)

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  ACTUALPrice Volume  \
# 0              1128  BROWN-FORMAN CORP             1233        36.99   1750
# 1              4425        MARTIGNETTI COMPANIES   3405        28.99   1750
# 2             17035  PERNOD RICARD USA             8068        24.99   1750
# 3              3960  DIAGEO NORTH AMERICA INC      4261        22.99   1750
# 4              3960  DIAGEO NORTH AMERICA INC      3545        29.99   1750
# ...             ...                          ...    ...          ...    ...
# 10687          9815  WINE GROUP INC                8527         4.99    750
# 10688          8004  SAZERAC CO INC                5683         0.49     50
# 10689          3924  HEAVEN HILL DISTILLERIES      9123         0.99     50
# 10690          3960  DIAGEO NORTH AMERICA INC      6127         1.99    200
# 10691          7245  PROXIMO SPIRITS INC.          3065         0.99     50
#
#        PurchasePrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0              26.27                 145080            3811251.60
# 1              23.19                 164038            3804041.22
# 2              18.24                 187407            3418303.68
# 3              16.17                 201682            3261197.94
# 4              21.89                 138109            3023206.01
# ...              ...                    ...                   ...
# 10687           1.32                      2                  2.64
# 10688           0.39                      6                  2.34
# 10689           0.74                      2                  1.48
# 10690           1.47                      1                  1.47
# 10691           0.71                      1                  0.71
#
#        TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  TotalExciseTax  \
# 0             5101919.51        672819.31            142049.0       260999.20
# 1             4819073.49        561512.37            160247.0       294438.66
# 2             4538120.60        461140.15            187140.0       343854.07
# 3             4475972.88        420050.01            200412.0       368242.80
# 4             4223107.62        545778.28            135838.0       249587.83
# ...                  ...              ...                 ...             ...
# 10687              15.95            10.96                 5.0            0.55
# 10688              65.66             1.47               134.0            7.04
# 10689               1.98             0.99                 2.0            0.10
# 10690             143.28            77.61                72.0           15.12
# 10691              85.14            33.66                86.0            4.46
#
#        FreightCost
# 0         68601.68
# 1        144929.24
# 2        123780.22
# 3        257032.07
# 4        257032.07
# ...            ...
# 10687     27100.41
# 10688     50293.62
# 10689     14069.87
# 10690    257032.07
# 10691     38994.78
#
# [10692 rows x 13 columns]

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# ACTUALPrice                0
# Volume                     0
# PurchasePrice              0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesDollars        178
# TotalSalesPrice          178
# TotalSalesQuantity       178
# TotalExciseTax           178
# FreightCost                0
# dtype: int64

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
#        'MHW LTD                    ', 'WINE GROUP INC             ',
#        'PERFECTA WINES             ', 'LUXCO INC                  ',
#        'TREASURY WINE ESTATES      ', 'DIAGEO CHATEAU ESTATE WINES',
#        'SHAW ROSS INT L IMP LTD    ', 'PINE STATE TRADING CO      ',
#        'PHILLIPS PRODUCTS CO.      ', 'CALEDONIA SPIRITS INC      ',
#        'STATE WINE & SPIRITS   ', 'KOBRAND CORPORATION        ',
#        'BANFI PRODUCTS CORP        ', 'VINEYARD BRANDS INC        ',
#        'DELICATO VINEYARDS INC     ', 'FABRIZIA SPIRITS LLC       ',
#        'DUGGANS DISTILLED PRODUCTS ', 'Serralles Usa LLC          ',
#        'SEA HAGG DISTILLERY LLC    ', 'OLE SMOKY DISTILLERY LLC   ',
#        'VRANKEN AMERICA            ', 'KLIN SPIRITS LLC           ',
#        'LAIRD & CO                 ', 'ADAMBA IMPORTS INTL INC    ',
#        'LATITUDE BEVERAGE COMPANY  ', 'FREDERICK WILDMAN & SONS   ',
#        'MCCORMICK DISTILLING CO    ', 'CHARLES JACQUIN ET CIE INC ',
#        'WESTERN SPIRITS BEVERAGE CO', 'MARSALLE COMPANY           ',
#        'AMERICAN VINTAGE BEVERAGE  ', 'MANGO BOTTLING INC         ',
#        'SWEET BABY VINEYARD        ', 'NICHE W & S                ',
#        'LABELLE VYDS AND WINERY    ', 'FLAG HILL WINERY & VINEYARD',
#        'SMOKY QUARTZ DISTILLERY LLC', 'PREMIUM PORT WINES, INC.   ',
#        'Russian Standard Vodka     ', 'Dunn Wine Brokers          ',
#        'WEIN BAUER INC             ', 'BULLY BOY DISTILLERS       ',
#        'ATLANTIC IMPORTING COMPANY ', 'PREMIER DISTRIBUTORS       ',
#        'VINILANDIA USA             ', 'PARK STREET IMPORTS LLC    ',
#        'TAKARA SAKE USA INC        ', 'SEA BREEZE CELLARS LLC     ',
#        'STARK BREWING COMPANY      ', 'TY KU LLC                  ',
#        'PSP WINES ', 'TAMWORTH DISTILLING        ',
#        'ZORVINO VINEYARDS          ', 'SOUTHERN GLAZERS W&S OF NE ',
#        'HOOD RIVER DISTILLERS, Inc.', 'CRUSH WINES                ',
#        'POVERTY LANE ORCHARDS      ', 'DJINN SPIRITS LLC          ',
#        'MOONLIGHT MEADERY          ', 'TALL SHIP DISTILLERY LLC   ',
#        'FORTUNE WINE BROKERS LLC   ', 'BLACK COVE BEVERAGES       ',
#        'VINEXTRA INC               ', 'SURVILLE ENTERPRISES CORP  ',
#        'JEWELL TOWNE VINEYARDS     ', 'SWEETWATER FARM         ',
#        'MARTIGNETTI COMPANIES ', 'ALTAMAR BRANDS LLC         ',
#        'CANDIA VINEYARDS           ', 'INCREDIBREW INC            ',
#        'ALISA CARR BEVERAGES           ', 'STELLAR IMPORTING CO LLC   ',
#        'FULCHINO VINEYARD INC      ',
#        'IRA GOLDMAN AND WILLIAMS, LLP          ',
#        'Circa Wines                ', 'VINEDREA WINES LLC         ',
#        'BLACK PRINCE DISTILLERY INC', 'VINEYARD BRANDS LLC        ',
#        'THE IMPORTED GRAPE LLC     ', 'WALPOLE MTN VIEW WINERY    ',
#        'GILMANTON WINERY & VINEYARD', 'HAUNTING WHISPER VYDS      ',
#        'STAR INDUSTRIES INC.       ', 'LOYAL DOG WINERY           ',
#        'R.P.IMPORTS INC            ', 'THE PIERPONT GROUP LLC     ',
#        'APPOLO VINEYARDS LLC       ', 'BLACK ROCK SPIRITS LLC     ',
#        'CENTEUR IMPORTS LLC        ', 'HIGHLAND WINE MERCHANTS LLC',
#        'AMERICAN SPIRITS EXCHANGE  ', 'UNCORKED       ',
#        'BRONCO WINE COMPANY        ', 'MILTONS DISTRIBUTING CO    ',
#        'TRUETT HURST               ', 'LAUREATE IMPORTS CO        ',
#        'FANTASY FINE WINES CORP    ', 'AAPER ALCOHOL & CHEMICAL CO',
#        'SILVER MOUNTAIN CIDERS     ', 'CAPSTONE INTERNATIONAL     ',
#        'FLAVOR ESSENCE INC         '], dtype=object)

# %%
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'].str.strip()

# %%
vendor_sales_summary['Volume'] = (
    vendor_sales_summary['Volume']
    .str.replace(r'[^\d.]', '', regex=True)
    .astype(float)
)

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# ACTUALPrice              float64
# Volume                   float64
# PurchasePrice            float64
# TotalPurchaseQuantity      int64
# TotalPurchaseDollars     float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalSalesQuantity       float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary.fillna(0, inplace = True)

# %%
vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesDollars'] - vendor_sales_summary['TotalPurchaseDollars']

# %%
vendor_sales_summary.head()
# Out:
#    VendorNumber                VendorName  Brand  ACTUALPrice  Volume  \
# 0          1128         BROWN-FORMAN CORP   1233        36.99  1750.0
# 1          4425     MARTIGNETTI COMPANIES   3405        28.99  1750.0
# 2         17035         PERNOD RICARD USA   8068        24.99  1750.0
# 3          3960  DIAGEO NORTH AMERICA INC   4261        22.99  1750.0
# 4          3960  DIAGEO NORTH AMERICA INC   3545        29.99  1750.0
#
#    PurchasePrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          26.27                 145080            3811251.60
# 1          23.19                 164038            3804041.22
# 2          18.24                 187407            3418303.68
# 3          16.17                 201682            3261197.94
# 4          21.89                 138109            3023206.01
#
#    TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  TotalExciseTax  \
# 0         5101919.51        672819.31            142049.0       260999.20
# 1         4819073.49        561512.37            160247.0       294438.66
# 2         4538120.60        461140.15            187140.0       343854.07
# 3         4475972.88        420050.01            200412.0       368242.80
# 4         4223107.62        545778.28            135838.0       249587.83
#
#    FreightCost  GrossProfit
# 0     68601.68   1290667.91
# 1    144929.24   1015032.27
# 2    123780.22   1119816.92
# 3    257032.07   1214774.94
# 4    257032.07   1199901.61

# %%
vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesDollars'])

# %%
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/ vendor_sales_summary['TotalPurchaseQuantity']

# %%
vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesDollars']/vendor_sales_summary['TotalPurchaseDollars']

# %%
vendor_sales_summary.head()
# Out:
#    VendorNumber                VendorName  Brand  ACTUALPrice  Volume  \
# 0          1128         BROWN-FORMAN CORP   1233        36.99  1750.0
# 1          4425     MARTIGNETTI COMPANIES   3405        28.99  1750.0
# 2         17035         PERNOD RICARD USA   8068        24.99  1750.0
# 3          3960  DIAGEO NORTH AMERICA INC   4261        22.99  1750.0
# 4          3960  DIAGEO NORTH AMERICA INC   3545        29.99  1750.0
#
#    PurchasePrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          26.27                 145080            3811251.60
# 1          23.19                 164038            3804041.22
# 2          18.24                 187407            3418303.68
# 3          16.17                 201682            3261197.94
# 4          21.89                 138109            3023206.01
#
#    TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  TotalExciseTax  \
# 0         5101919.51        672819.31            142049.0       260999.20
# 1         4819073.49        561512.37            160247.0       294438.66
# 2         4538120.60        461140.15            187140.0       343854.07
# 3         4475972.88        420050.01            200412.0       368242.80
# 4         4223107.62        545778.28            135838.0       249587.83
#
#    FreightCost  GrossProfit  ProfitMargin  StockTurnover  SalestoPurchaseRatio
# 0     68601.68   1290667.91      0.252977       0.979108              1.338647
# 1    144929.24   1015032.27      0.210628       0.976890              1.266830
# 2    123780.22   1119816.92      0.246758       0.998575              1.327594
# 3    257032.07   1214774.94      0.271399       0.993703              1.372493
# 4    257032.07   1199901.61      0.284128       0.983556              1.396897

# %%
cursor = conn.cursor()
cursor.execute("""
CREATE TABLE vendor_sales_summary (
    VendorNumber INT,
    VendorName VARCHAR(100),
    Brand INT,
    ACTUALPrice DECIMAL(10, 2),
    Volume DECIMAL(10, 2),
    PurchasePrice DECIMAL(10, 2),
    TotalPurchaseQuantity INT,
    TotalPurchaseDollars DECIMAL(12, 2),
    TotalSalesDollars DECIMAL(12, 2),
    TotalSalesPrice DECIMAL(10, 2),
    TotalSalesQuantity INT,
    TotalExciseTax DECIMAL(10, 2),
    FreightCost DECIMAL(10, 2),
    GrossProfit DECIMAL(12, 2),
    ProfitMargin DECIMAL(5, 4),
    StockTurnover DECIMAL(10, 2),
    SalestoPurchaseRatio DECIMAL(10, 2),
    PRIMARY KEY (VendorNumber, Brand)
);
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[31], line 2
#       1 cursor = conn.cursor()
# ----> 2 cursor.execute("""
#       3 CREATE TABLE vendor_sales_summary (
#       4     VendorNumber INT,
#       5     VendorName VARCHAR(100),
#       6     Brand INT,
#       7     ACTUALPrice DECIMAL(10, 2),
#       8     Volume DECIMAL(10, 2),
#       9     PurchasePrice DECIMAL(10, 2),
#      10     TotalPurchaseQuantity INT,
#      11     TotalPurchaseDollars DECIMAL(12, 2),
#      12     TotalSalesDollars DECIMAL(12, 2),
#      13     TotalSalesPrice DECIMAL(10, 2),
#      14     TotalSalesQuantity INT,
#      15     TotalExciseTax DECIMAL(10, 2),
#      16     FreightCost DECIMAL(10, 2),
#      17     GrossProfit DECIMAL(12, 2),
#      18     ProfitMargin DECIMAL(5, 4),
#      19     StockTurnover DECIMAL(10, 2),
#      20     SalestoPurchaseRatio DECIMAL(10, 2),
#      21     PRIMARY KEY (VendorNumber, Brand)
#      22 );
#      23 """)
#
# OperationalError: table vendor_sales_summary already exists

# %%
vendor_sales_summary.to_sql('vendor_sales_summary',conn, if_exists = 'replace' , index = False)
# Out:
# 10692

# %%
pd.read_sql("""SELECT * FROM vendor_sales_summary""",conn)
# Out:
#        VendorNumber                VendorName  Brand  ACTUALPrice  Volume  \
# 0              1128         BROWN-FORMAN CORP   1233        36.99  1750.0
# 1              4425     MARTIGNETTI COMPANIES   3405        28.99  1750.0
# 2             17035         PERNOD RICARD USA   8068        24.99  1750.0
# 3              3960  DIAGEO NORTH AMERICA INC   4261        22.99  1750.0
# 4              3960  DIAGEO NORTH AMERICA INC   3545        29.99  1750.0
# ...             ...                       ...    ...          ...     ...
# 10687          9815            WINE GROUP INC   8527         4.99   750.0
# 10688          8004            SAZERAC CO INC   5683         0.49    50.0
# 10689          3924  HEAVEN HILL DISTILLERIES   9123         0.99    50.0
# 10690          3960  DIAGEO NORTH AMERICA INC   6127         1.99   200.0
# 10691          7245      PROXIMO SPIRITS INC.   3065         0.99    50.0
#
#        PurchasePrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0              26.27                 145080            3811251.60
# 1              23.19                 164038            3804041.22
# 2              18.24                 187407            3418303.68
# 3              16.17                 201682            3261197.94
# 4              21.89                 138109            3023206.01
# ...              ...                    ...                   ...
# 10687           1.32                      2                  2.64
# 10688           0.39                      6                  2.34
# 10689           0.74                      2                  1.48
# 10690           1.47                      1                  1.47
# 10691           0.71                      1                  0.71
#
#        TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  TotalExciseTax  \
# 0             5101919.51        672819.31            142049.0       260999.20
# 1             4819073.49        561512.37            160247.0       294438.66
# 2             4538120.60        461140.15            187140.0       343854.07
# 3             4475972.88        420050.01            200412.0       368242.80
# 4             4223107.62        545778.28            135838.0       249587.83
# ...                  ...              ...                 ...             ...
# 10687              15.95            10.96                 5.0            0.55
# 10688              65.66             1.47               134.0            7.04
# 10689               1.98             0.99                 2.0            0.10
# 10690             143.28            77.61                72.0           15.12
# 10691              85.14            33.66                86.0            4.46
#
#        FreightCost  GrossProfit  ProfitMargin  StockTurnover  \
# 0         68601.68   1290667.91      0.252977       0.979108
# 1        144929.24   1015032.27      0.210628       0.976890
# 2        123780.22   1119816.92      0.246758       0.998575
# 3        257032.07   1214774.94      0.271399       0.993703
# 4        257032.07   1199901.61      0.284128       0.983556
# ...            ...          ...           ...            ...
# 10687     27100.41        13.31      0.834483       2.500000
# 10688     50293.62        63.32      0.964362      22.333333
# 10689     14069.87         0.50      0.252525       1.000000
# 10690    257032.07       141.81      0.989740      72.000000
# 10691     38994.78        84.43      0.991661      86.000000
#
#        SalestoPurchaseRatio
# 0                  1.338647
# 1                  1.266830
# 2                  1.327594
# 3                  1.372493
# 4                  1.396897
# ...                     ...
# 10687              6.041667
# 10688             28.059829
# 10689              1.337838
# 10690             97.469388
# 10691            119.915493
#
# [10692 rows x 17 columns]
